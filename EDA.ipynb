# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Amazon.csv')

# %%
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     1997-05-15     2.437500     2.500000     1.927083     1.958333
# 1     1997-05-16     1.968750     1.979167     1.708333     1.729167
# 2     1997-05-19     1.760417     1.770833     1.625000     1.708333
# 3     1997-05-20     1.729167     1.750000     1.635417     1.635417
# 4     1997-05-21     1.635417     1.645833     1.375000     1.427083
# ...          ...          ...          ...          ...          ...
# 6150  2021-10-21  3414.250000  3440.280029  3403.000000  3435.010010
# 6151  2021-10-22  3421.000000  3429.840088  3331.300049  3335.550049
# 6152  2021-10-25  3335.000000  3347.800049  3297.699951  3320.370117
# 6153  2021-10-26  3349.510010  3416.120117  3343.979980  3376.070068
# 6154  2021-10-27  3388.000000  3412.000000  3371.453369  3396.189941
#
#         Adj Close    Volume  Year
# 0        1.958333  72156000  1997
# 1        1.729167  14700000  1997
# ...

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume
# 0  1997-05-15  2.437500  2.500000  1.927083  1.958333   1.958333  72156000
# 1  1997-05-16  1.968750  1.979167  1.708333  1.729167   1.729167  14700000
# 2  1997-05-19  1.760417  1.770833  1.625000  1.708333   1.708333   6106800
# 3  1997-05-20  1.729167  1.750000  1.635417  1.635417   1.635417   5467200
# 4  1997-05-21  1.635417  1.645833  1.375000  1.427083   1.427083  18853200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6155 entries, 0 to 6154
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       6155 non-null   object
#  1   Open       6155 non-null   float64
#  2   High       6155 non-null   float64
#  3   Low        6155 non-null   float64
#  4   Close      6155 non-null   float64
#  5   Adj Close  6155 non-null   float64
#  6   Volume     6155 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 336.7+ KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  6155.000000  6155.000000  6155.000000  6155.000000  6155.000000
# mean    520.556302   526.216132   514.277282   520.429832   520.429832
# std     857.161696   865.821041   847.270905   856.668492   856.668492
# min       1.406250     1.447917     1.312500     1.395833     1.395833
# 25%      38.750000    39.514999    38.104999    38.821251    38.821251
# 50%      92.669998    94.190002    90.750000    92.639999    92.639999
# 75%     528.949982   535.304993   521.950012   529.450012   529.450012
# max    3744.000000  3773.080078  3696.790039  3731.409912  3731.409912
#
#              Volume
# count  6.155000e+03
# mean   7.329010e+06
# std    7.149521e+06
# min    4.872000e+05
# 25%    3.579350e+06
# 50%    5.470000e+06
# 75%    8.294950e+06
# max    1.043292e+08

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df[['Open']].boxplot()
Q1 = np.percentile(df['Open'], 25,
                   method = 'midpoint')
Q3 = np.percentile(df['Open'], 75,
                   method = 'midpoint')
IQR = Q3 - Q1
print("Shape: ", df.shape)
 
# Upper bound
upper = np.where(df['Open'] >= (Q3+1.5*IQR))
# Lower bound
lower = np.where(df['Open'] <= (Q1-1.5*IQR))
print("Total Number Of Outliers",len(upper[0])+len(lower[0]))
# Out:
# Shape:  (6155, 7)
# Total Number Of Outliers 955

# %%
#Extreme Upper bound
e_upper = np.where(df['Open'] >= (Q3+3*IQR))
#Extreme Lower bound
e_lower = np.where(df['Open'] <= (Q1-3*IQR))
print("Total Number Of Extreme Outliers",len(e_upper[0])+len(e_lower[0]))
# Out:
# Total Number Of Extreme Outliers 425

# %%
df[['Close']].boxplot()
Q1 = np.percentile(df['Close'], 25,
                   method = 'midpoint')
Q3 = np.percentile(df['Close'], 75,
                   method = 'midpoint')
IQR = Q3 - Q1
print("Shape: ", df.shape)
 
# Upper bound
upper = np.where(df['Close'] >= (Q3+1.5*IQR))
# Lower bound
lower = np.where(df['Close'] <= (Q1-1.5*IQR))
print("Total Number Of Outliers",len(upper[0])+len(lower[0]))
# Out:
# Shape:  (6155, 7)
# Total Number Of Outliers 956

# %%
#Extreme Upper bound
e_upper = np.where(df['Close'] >= (Q3+3*IQR))
#Extreme Lower bound
e_lower = np.where(df['Close'] <= (Q1-3*IQR))
print("Total Number Of Extreme Outliers",len(e_upper[0])+len(e_lower[0]))
# Out:
# Total Number Of Extreme Outliers 420

# %%
df[['Low']].boxplot()
Q1 = np.percentile(df['Low'], 25,
                   method = 'midpoint')
Q3 = np.percentile(df['Low'], 75,
                   method = 'midpoint')
IQR = Q3 - Q1
print("Shape: ", df.shape)
 
# Upper bound
upper = np.where(df['Low'] >= (Q3+1.5*IQR))
# Lower bound
lower = np.where(df['Low'] <= (Q1-1.5*IQR))
print("Total Number Of Outliers",len(upper[0])+len(lower[0]))
# Out:
# Shape:  (6155, 7)
# Total Number Of Outliers 956

# %%
# Extreme Upper bound
e_upper = np.where(df['Low'] >= (Q3+3*IQR))
# Extreme Lower bound
e_lower = np.where(df['Low'] <= (Q1-3*IQR))
print("Total Number Of Extreme Outliers",len(e_upper[0])+len(e_lower[0]))
# Out:
# Total Number Of Extreme Outliers 424

# %%
df[['High']].boxplot()
Q1 = np.percentile(df['High'], 25,
                   method = 'midpoint')
Q3 = np.percentile(df['High'], 75,
                   method = 'midpoint')
IQR = Q3 - Q1
print("Shape: ", df.shape)
 
# Upper bound
upper = np.where(df['High'] >= (Q3+1.5*IQR))
# Lower bound
lower = np.where(df['High'] <= (Q1-1.5*IQR))
print("Total Number Of Outliers",len(upper[0])+len(lower[0]))
# Out:
# Shape:  (6155, 7)
# Total Number Of Outliers 955

# %%
# Extreme Upper bound
e_upper = np.where(df['High'] >= (Q3+3*IQR))
# Extreme Lower bound
e_lower = np.where(df['High'] <= (Q1-3*IQR))
print("Total Number Of Extreme Outliers",len(e_upper[0])+len(e_lower[0]))
# Out:
# Total Number Of Extreme Outliers 420

# %%
df[['Adj Close']].boxplot()
Q1 = np.percentile(df['Adj Close'], 25,
                   method = 'midpoint')
Q3 = np.percentile(df['Adj Close'], 75,
                   method = 'midpoint')
IQR = Q3 - Q1
print("Shape: ", df.shape)
 
# Upper bound
upper = np.where(df['Adj Close'] >= (Q3+1.5*IQR))
# Lower bound
lower = np.where(df['Adj Close'] <= (Q1-1.5*IQR))
print("Total Number Of Outliers",len(upper[0])+len(lower[0]))
# Out:
# Shape:  (6155, 7)
# Total Number Of Outliers 956

# %%
# Extreme Upper bound
e_upper = np.where(df['Adj Close'] >= (Q3+3*IQR))
# Extreme Lower bound
e_lower = np.where(df['Adj Close'] <= (Q1-3*IQR))
print("Total Number Of Extreme Outliers",len(e_upper[0])+len(e_lower[0]))
# Out:
# Total Number Of Extreme Outliers 420

# %%
df1=df.drop(['Date'], axis=1)

# %%
corr = df1.corr()# plot the heatmap
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
corr = df1.corr(method="pearson")
corr
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999934  0.999912  0.999842   0.999842 -0.240087
# High       0.999934  1.000000  0.999893  0.999924   0.999924 -0.238907
# Low        0.999912  0.999893  1.000000  0.999928   0.999928 -0.241351
# Close      0.999842  0.999924  0.999928  1.000000   1.000000 -0.240122
# Adj Close  0.999842  0.999924  0.999928  1.000000   1.000000 -0.240122
# Volume    -0.240087 -0.238907 -0.241351 -0.240122  -0.240122  1.000000

# %%
df['Year'] = pd.DatetimeIndex(df['Date']).year
df.plot(kind='scatter', x='Year', y='High')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='High'>

# %%
df.plot(kind='scatter', x='Year', y='Volume')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Volume'>

# %%
df1[['Open','Close']].head(60).plot(kind='bar',figsize=(16,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='blue')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='green')
plt.show()

# %%
import plotly.express as px
fig = px.line(df, x = 'Date', y = 'Open', title = 'Opening stock price 1997-2021')
fig.show()
# Out:
# <div>                            <div id="bce52040-f161-408a-82c4-09d2af0fec21" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bce52040-f161-408a-82c4-09d2af0fec21")) {                    Plotly.newPlot(                        "bce52040-f161-408a-82c4-09d2af0fec21",                        [{"hovertemplate":"Date=%{x}<br>Open=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["1997-05-15","1997-05-16","1997-05-19","1997-05-20","1997-05-21","1997-05-22","1997-05-23","1997-05-27","1997-05-28","1997-05-29","1997-05-30","1997-06-02","1997-06-03","1997-06-04","1997-06-05","1997-06-06","1997-06-09","1997-06-10","1997-06-11","1997-06-12","1997-06-13",
# ...

# %%
fig = px.line(df, x = 'Date', y = 'Close', title = 'Closing stock price 1997-2021')
fig.show()
# Out:
# <div>                            <div id="411858fd-c99e-4cde-862f-f2a406c40c1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("411858fd-c99e-4cde-862f-f2a406c40c1f")) {                    Plotly.newPlot(                        "411858fd-c99e-4cde-862f-f2a406c40c1f",                        [{"hovertemplate":"Date=%{x}<br>Close=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["1997-05-15","1997-05-16","1997-05-19","1997-05-20","1997-05-21","1997-05-22","1997-05-23","1997-05-27","1997-05-28","1997-05-29","1997-05-30","1997-06-02","1997-06-03","1997-06-04","1997-06-05","1997-06-06","1997-06-09","1997-06-10","1997-06-11","1997-06-12","1997-06-13"
# ...

# %%
fig = px.line(df, x = 'Date', y = 'Low', title = 'Low stock price for each day between 1997-2021')
fig.show()
fig = px.line(df, x = 'Date', y = 'High', title = 'High stock price for each day between 1997-2021')
fig.show()
# Out:
# <div>                            <div id="129ffc9a-7656-4a53-b5ea-3119d926b7ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("129ffc9a-7656-4a53-b5ea-3119d926b7ad")) {                    Plotly.newPlot(                        "129ffc9a-7656-4a53-b5ea-3119d926b7ad",                        [{"hovertemplate":"Date=%{x}<br>Low=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["1997-05-15","1997-05-16","1997-05-19","1997-05-20","1997-05-21","1997-05-22","1997-05-23","1997-05-27","1997-05-28","1997-05-29","1997-05-30","1997-06-02","1997-06-03","1997-06-04","1997-06-05","1997-06-06","1997-06-09","1997-06-10","1997-06-11","1997-06-12","1997-06-13","
# ...

# %%
fig = px.line(df, x = 'Date', y = 'Volume', title = 'Volume of stock traded for each day between 1997-2021')
fig.show()
# Out:
# <div>                            <div id="05d7115a-2535-4128-a7ac-2248fe9be7c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("05d7115a-2535-4128-a7ac-2248fe9be7c8")) {                    Plotly.newPlot(                        "05d7115a-2535-4128-a7ac-2248fe9be7c8",                        [{"hovertemplate":"Date=%{x}<br>Volume=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["1997-05-15","1997-05-16","1997-05-19","1997-05-20","1997-05-21","1997-05-22","1997-05-23","1997-05-27","1997-05-28","1997-05-29","1997-05-30","1997-06-02","1997-06-03","1997-06-04","1997-06-05","1997-06-06","1997-06-09","1997-06-10","1997-06-11","1997-06-12","1997-06-13
# ...

# %%
sns.pairplot(df1)

# %%
df_min_max_scaled = df1.copy()
  
# apply normalization techniques
for column in df_min_max_scaled.columns:
    df_min_max_scaled[column] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min())    
  
# view normalized data
df_min_max_scaled
# Out:
#           Open      High       Low     Close  Adj Close    Volume
# 0     0.000276  0.000279  0.000166  0.000151   0.000151  0.690172
# 1     0.000150  0.000141  0.000107  0.000089   0.000089  0.136869
# 2     0.000095  0.000086  0.000085  0.000084   0.000084  0.054117
# 3     0.000086  0.000080  0.000087  0.000064   0.000064  0.047957
# 4     0.000061  0.000052  0.000017  0.000008   0.000008  0.176865
# ...        ...       ...       ...       ...        ...       ...
# 6150  0.911893  0.911762  0.920500  0.920537   0.920537  0.013426
# 6151  0.913696  0.908994  0.901098  0.893872   0.893872  0.025487
# 6152  0.890718  0.887242  0.892006  0.889802   0.889802  0.016745
# 6153  0.894594  0.905357  0.904529  0.904735   0.904735  0.021249
# 6154  0.904879  0.904264  0.911964  0.910129   0.910129  0.005711
#
# [6155 rows x 6 columns]
